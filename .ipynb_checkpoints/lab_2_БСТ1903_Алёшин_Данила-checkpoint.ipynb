# %% [markdown]
# # Лабораторная работа №2
# ## Выполнил студент группы БСТ1903 Алёшин Данила
# ### Задание №1
# Реализовать методы поиска в соответствии с заданием. Организовать генерацию
# начального набора случайных данных. Для всех вариантов добавить реализацию
# добавления, поиска и удаления элементов. Оценить время работы каждого алгоритма
# поиска и сравнить его со временем работы стандартной функции поиска, используемой в
# выбранном языке программирования.
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA.PNG](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA.PNG)

# %% [markdown]
# ### Бинарный поиск

# %%
import numpy
def binarniy(mass, n):
    rigth=int(len(mass))
    rigth=rigth-1
    left=int(0)
    while (n > mass[int(left+((rigth-left)/2))]) or (n < mass[int(left+((rigth-left)/2))]):
       # print(int((rigth-left)/2))
        if n>mass[int(left+((rigth-left)/2))]:
            left=int(left+((rigth-left)/2))
        if n<mass[int(left+((rigth-left)/2))]:
            rigth=int(left+((rigth-left)/2))
    if mass[int(left+((rigth-left)/2))]==n:
        return int(left+((rigth-left)/2))
    return -1

# %% [markdown]
# ### Бинарное дерево

# %% [markdown]
# ### Фибоначчиев поиск

# %%
def search_Fibonacci(mass, n):
    fib1=0
    fib2=1
    fibm=fib1+fib2
    while len(mass)>fibm:
        fib1=fib2
        fib2=fibm
        fibm=fib1+fib2
    index=-1
    while (fibm>1):
        i=min(index+fib1, len(mass)-1)
        if (mass[i]<n):# если n больше элемента, то переместить три переменные Фибоначчи на одну вниз и сбросить индекс до i
            fibm=fib2
            fib2=fib1
            fib1=fibm-fib2
            index=i
        elif (mass[i]>n):#если n меньше элемента, то переместить три переменные Фибоначчи на 2 вниз
            fibm=fib1
            fib2=fib2-fib1
            fib1=fibm-fib2
        else:#
            return i
    if (fib2 and index<(len(mass)-1) and mass[index+1]==n):
        return index+1
    return -1

# %% [markdown]
# ### Интерполяционный поиск

# %%
def Interpolation_search(mass, n):
    rigth=int(len(mass)-1)
    left=0
    while rigth>=left and n>=mass[left] and n<=mass[rigth]:
        index=left+int(((float(rigth-left)/(mass[rigth]-mass[left]))*(n-mass[left])))
        if (mass[index]==n):
            return index
        elif (mass[index]<n):
            left=index+1
        else:
            rigth=index-1
    return -1

# %% [markdown]
# ### Генерация массива длинной n

# %%
def matrixgenerate():
    n=int(input('Введите длину массива'))
    massiv = numpy.random.random_integers(0, 20, size=(n))
    massiv=sorted(massiv)
    for i, j in enumerate(massiv):
        print("massiv[", i, "]=", j)
    return massiv

# %% [markdown]
# ### Вызов

# %%
massiv=matrixgenerate()
print("Массив сгенерирован. Выберите следующее действие")
ln=int(1)
while ln==1:
    print("1. Добавить новый элемент \n2. Найти элемент\n3. Удалить элемент")
    var=int(input())#Выбор действия 1- добавить элемент 2- найти элемент 3- удалить элемент
    if var ==1:
        print("Введите элемент")
        new_element=int(input())
        massiv.insert(len(massiv), new_element)
        massiv=sorted(massiv)
        for i, j in enumerate(massiv):
            print("massiv[", i, "]=", j)
        print("Продолжит действия с массивом?\n1. Продолжить\n2. Завершить работу")
        ln=int(input())
    if var==3:
        print("Введите элемент")
        delete_element=int(input())
        del(massiv[delete_element])
        for i, j in enumerate(massiv):
            print("massiv[", i, "]=", j)
        print("Продолжит действия с массивом?\n1. Продолжить\n2. Завершить работу")
        ln=int(input())
    if var==2:
        print("Выберите алгоритм поиска\n1. Бинарный поиск\n2. Фибоначчиев поиск\n3. Интерполяционный поиск")
        var=int(input())#выбор алгоритма поиска 1- бинарный поиск 2-Фибоначчиев поиск 3- Интерполяционный поиск
        
        if var==1:
            print("Введите элемент который необходимо найти:")
            search_element=int(input())
            index=binarniy(massiv, search_element)
            if index==-1:
                print("элемент не найден")
            else:
                print(index)
        if var==2:
            print("Введите элемент который необходимо найти:")
            search_element=int(input())
            index=search_Fibonacci(massiv, search_element)
            if index==-1:
                print("элемент не найден")
            else:
                print(index)
        if var==3:
            print("Введите элемент который необходимо найти:")
            search_element=int(input())
            index=Interpolation_search(massiv, search_element)
            if index==-1:
                print("элемент не найден")
            else:
                print(index)
                #
                
        print("Продолжит действия с массивом?\n1. Продолжить\n2. Завершить работу")
        ln=int(input())
# Out:
# Введите длину массива4
# <ipython-input-27-6c543a076e22>:3: DeprecationWarning: This function is deprecated. Please call randint(0, 20 + 1) instead
#   massiv = numpy.random.random_integers(0, 20, size=(n))
# massiv[ 0 ]= 5
# massiv[ 1 ]= 12
# massiv[ 2 ]= 14
# massiv[ 3 ]= 20
# Массив сгенерирован. Выберите следующее действие
# 1. Добавить новый элемент
# 2. Найти элемент
# 3. Удалить элемент
# 3
# Введите элемент
# 0
# massiv[ 0 ]= 12
# massiv[ 1 ]= 14
# massiv[ 2 ]= 20
# Продолжит действия с массивом?
# 1. Продолжить
# 2. Завершить работу
# 1
# 1. Добавить новый элемент
# 2. Найти элемент
# 3. Удалить элемент
# 1
# Введите элемент
# 1
# massiv[ 0 ]= 1
# massiv[ 1 ]= 12
# massiv[ 2 ]= 14
# massiv[ 3 ]= 20
# Продолжит действия с массивом?
# 1. Продолжить
# 2. Завершить работу
# 1
# 1. Добавить новый элемент
# 2. Найти элемент
# 3. Удалить элемент
# 2
# Выберите алгоритм поиска
# 1. Бинарный поиск
# 2. Фибоначчиев поиск
# 3. Интерполяционный поиск
# 1
# Введите элемент который необходимо найти:
# 1
# 0
# Продолжит действия с массивом?
# 1. Продолжить
# 2. Завершить работу
# 1
# 1. Добавить новый элемент
# 2. Найти элемент
# 3. Удалить элемент
# 2
# Выберите алгоритм поиска
# 1. Бинарный поиск
# 2. Фибоначчиев поиск
# 3. Интерполяционный поиск
# 2
# Введите элемент который необходимо найти:
# 1
# 0
# Продолжит действия с массивом?
# 1. Продолжить
# 2. Завершить работу
# 1
# 1. Добавить новый элемент
# 2. Найти элемент
# 3. Удалить элемент
# 2
# Выберите алгоритм поиска
# 1. Бинарный поиск
# 2. Фибоначчиев поиск
# 3. Интерполяционный поиск
# 3
# Введите элемент который необходимо найти:
# 1
# 0
# Продолжит действия с массивом?
# 1. Продолжить
# 2. Завершить работу
# 2

# %% [markdown]
# # Задание №2
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA.PNG](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA.PNG)

# %% [markdown]
# ### Простое рехэширование

# %%
import random
#Простое рехэширование
def prost_rehash(mashash, a):
    i=int(0)
    n=0
    s=1
    while s==1:
        n=(ord(a[0])+i)%(len(mashash))
        if mashash[n]== "":
            mashash[n]=a
            s=0
        else:
            i+=1
#Поиск 
def search_prost_rehash(mashash, a):
    i=int(0)
    n=0
    s=1
    while s==1:
        n=(ord(a[0])+i)%(len(mashash))
        if mashash[n]== a:
            return n
        elif(mashash[n]==""):
            return -1
        else:
            i+=1
#

# %% [markdown]
# ### Рехэширование с использованием псевдослучайных чисел

# %%
def rehash(mashash, a):
    l=0
    n=0
    s=1
    while s==1:
        random.seed(l)
        i=int((random.random()*10000000000000000)%1000)
        n=(ord(a[0])+i)%(len(mashash))
        if mashash[n]== "":
            mashash[n]=a
            s=0
        else:
            l+=1
#Поиск
def search_rehash(mashash, a):
    l=0
    n=0
    s=1
    while s==1:
        random.seed(l)
        i=int((random.random()*10000000000000000)%1000)
        n=(ord(a[0])+i)%(len(mashash))
        if mashash[n]== "":
            return -1
        elif mashash[n]==a:
            return n
        else:
            l+=1
#

# %% [markdown]
# ### Метод цепочек

# %%
def chain_method(mashash, a):
    key=0
    for i in range(0, len(a)):
        key=key+ord(a[i])
    key=key%10
    mashash[key].append(a)

#Поиск
def search_chain_method(mashash, a):
    key=0
    for i in range(0, len(a)):
        key=key+ord(a[i])
    key=key%10
    for i in range(len(mashash[key])):
        if mashash[key][i]==a:
            return key, i
    
    return key, -1
#

# %% [markdown]
# ### Вывод

# %%
ln=1
while ln==1:
    print("Выберите метод рехэширования\n1.Простое рехэширование\n2.Рехэширование с использованием псевдослучайных числе\n3.Метод цепочек")
    var=int(input())

    if var==3:#реализация метода цепочек
        mass=[[]*1 for i in range(10)]
        print("Введите количество элементов, которые необходимо добавить")
        colelement=int(input())
        elements=[""]*colelement
        print("Введите элементы которые необходимо добавить")
        for i in range(colelement):
            elements[i]=(input()) #ввод элементов
        for i in range(len(elements)):
            chain_method(mass, elements[i]) #реализация метода цепочек
        print(mass)
        print("Найти элемент?\n1. Да\n2. Нет")
        ot=int(input())
        while(ot==1):
            print("Введите элемент")
            s=input()
            key, s=search_chain_method(mass, s)#поиск
            if(s>-1):
                print("Элемент найден. Удалить элемент?\n1. Да\n2. Нет\n")
                dl=int(input())
                if(dl==1):
                    del(mass[key][s])
                    print(mass)
            else:
                print("Элемент не найдет")
            print("Найти элемент?\n1. Да\n2. Нет")
            ot=int(input())
        print("Продолжить работу\n1.Да\n2. Нет")
        ln=int(input())
        
    if var==1:# Простое рехэширование
        mass=([""]*256)
        print("Введите количество элементов, которые необходимо добавить")
        colelement=int(input())
        elements=[""]*colelement
        print("Введите элементы которые необходимо добавить")
        for i in range(colelement):
            elements[i]=(input())#ввод элементов
        for i in range(len(elements)):
            prost_rehash(mass, elements[i])
        print(mass)
        print("Найти элемент?\n1. Да\n2. Нет")
        ot=int(input())
        while(ot==1):
            print("Введите элемент")
            s=input()
            s=search_prost_rehash(mass, s)#поиск
            if(s>-1):
                print("Элемент найден. Удалить элемент?\n1. Да\n2. Нет\n")
                dl=int(input())
                if(dl==1):
                    del(mass[s])
            else:
                print("Элемент не найдет")
            print("Найти элемент?\n1. Да\n2. Нет")
            ot=int(input())
        print("Продолжить работу\n1.Да\n2. Нет")
        ln=int(input())
        
    if var==2:# Рехэширование с использование псевдослучайных чисел
        mass=([""]*256)
        print("Введите количество элементов, которые необходимо добавить")
        colelement=int(input())
        elements=[""]*colelement
        print("Введите элементы которые необходимо добавить")
        for i in range(colelement):
            elements[i]=(input())#ввод элементов
        for i in range(len(elements)):
            rehash(mass, elements[i])
        print(mass)
        print("Найти элемент?\n1. Да\n2. Нет")
        ot=int(input())
        while(ot==1):
            print("Введите элемент")
            s=input()
            s=search_rehash(mass, s)#поиск
            if(s>-1):
                print("Элемент найден. Удалить элемент?\n1. Да\n2. Нет\n")
                dl=int(input())
                if(dl==1):
                    del(mass[s])
            else:
                print("Элемент не найдет")
            print("Найти элемент?\n1. Да\n2. Нет")
            ot=int(input())
        print("Продолжить работу\n1. Да\n2. Нет")
        ln=int(input())
# Out:
# Выберите метод рехэширования
# 1.Простое рехэширование
# 2.Рехэширование с использованием псевдослучайных числе
# 3.Метод цепочек
# 2
# Введите количество элементов, которые необходимо добавить
# 4
# Введите элементы которые необходимо добавить
# qwe
# qww
# ewq
# 123
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '123', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'ewq', '', '', '', '', '', '', '', '', '', '', '', 'qwe', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'qww', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# Найти элемент?
# 1. Да
# 2. Нет
# 1
# Введите элемент
# 123
# Элемент найден. Удалить элемент?
# 1. Да
# 2. Нет
#
# 1
# Найти элемент?
# 1. Да
# 2. Нет
# 1
# Введите элемент
# 123
# Элемент не найдет
# Найти элемент?
# 1. Да
# 2. Нет
# 2
# Продолжить работу
# 1. Да
# 2. Нет
# 2

# %% [markdown]
# ## Задание №3
# Расставить на стандартной 64-клеточной шахматной доске 8 ферзей так, чтобы ни
# один из них не находился под боем другого». Подразумевается, что ферзь бьёт все клетки,
# расположенные по вертикалям, горизонталям и обеим диагоналям
# Написать программу, которая находит хотя бы один способ решения задач.

# %%
even=list(range(1,8,2))
odd=list(range(2,8,2))
odd[1]=0
odd.append(4)
rez=even+odd
row=["."]*8
for i in range(8):
    j=rez[i]
    row[j]="Ф"
    print(*row)
    row[j]="."
i=7
print("\n")
while i>=0:
    j=rez[i]
    row[j]="Ф"
    print(*row)
    row[j]="."
    i-=1
# Out:
# . Ф . . . . . .
# . . . Ф . . . .
# . . . . . Ф . .
# . . . . . . . Ф
# . . Ф . . . . .
# Ф . . . . . . .
# . . . . . . Ф .
# . . . . Ф . . .
#
#
# . . . . Ф . . .
# . . . . . . Ф .
# Ф . . . . . . .
# . . Ф . . . . .
# . . . . . . . Ф
# . . . . . Ф . .
# . . . Ф . . . .
# . Ф . . . . . .
